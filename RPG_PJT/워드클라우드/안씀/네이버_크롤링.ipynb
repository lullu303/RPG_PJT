# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import selenium
from selenium import webdriver
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By # 셀레니움 4.0부터 포함된 함수(필수)
from urllib.request import urlopen
import requests

# %%
driver = webdriver.Chrome('./driver/chromedriver.exe')
# Out:
# C:\Users\jihye\AppData\Local\Temp\ipykernel_8452\3506397282.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./driver/chromedriver.exe')

# %%
# 웹사이트
driver.get("https://www.naver.com")
driver.implicitly_wait(10) # 10초 대기

# %%
#query

# %%
# 검색창 선택 후 클릭
search = driver.find_element(By.CSS_SELECTOR,'#query')
search.click()

#sform > fieldset > div > input
#query

# %%
# 검색어 입력
search.send_keys('콘솔게임시장 현황')

# %%
# 엔터키 전송
search.send_keys(Keys.ENTER)

# %%
# 뉴스메뉴 클릭
driver.find_element(By.CSS_SELECTOR,'#lnb > div.lnb_group > div > ul > li:nth-child(8) > a').click()
time.sleep(2)

# %%
# # 스크롤 실행 전 높이
# before_h = driver.execute_script('return window.scrollY')
# before_h

# %%
# # 무한 스크롤
# # body태그 객체를 찾고 키보드의 end키를 전송
# while True :
#     # 현재 화면의 맨 아래로 스크롤을 내리기
#     driver.find_element(By.CSS_SELECTOR,'body').send_keys(Keys.END)
#     # 스크롤 후 페이지 로딩시간 대기
#     time.sleep(1)
    
#     # 스크롤 후 현재 위치
#     after_h = driver.execute_script('return window.scrollY')
#     print(after_h)
#     if after_h == before_h :
#         break
#     before_h = after_h

# %%
url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query=%EC%BD%98%EC%86%94%EA%B2%8C%EC%9E%84%EC%8B%9C%EC%9E%A5+%ED%98%84%ED%99%A9'

# %%
res = urlopen(url)
res.read()
# Out:
# b'<!doctype html> <html lang="ko"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="\xec\xbd\x98\xec\x86\x94\xea\xb2\x8c\xec\x9e\x84\xec\x8b\x9c\xec\x9e\xa5 \xed\x98\x84\xed\x99\xa9 : \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\x89\xb4\xec\x8a\xa4\xea\xb2\x80\xec\x83\x89"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'\xec\xbd\x98\xec\x86\x94\xea\xb2\x8c\xec\x9e\x84\xec\x8b\x9c\xec\x9e\xa5 \xed\x98\x84\xed\x99\xa9\'\xec\x9d\x98 \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\x89\xb4\xec\x8a\xa4\xea\xb2\x80\xec\x83\x89 \xea\xb2\xb0\xea\xb3\xbc\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4."> <meta name="description" lang="ko" content="\'\xec\xbd\x98\xec\x86\x94\xea\xb2\x8c\xec\x9e\x84\xec\x8b\x9c\xe
# ...

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36"}
res = requests.get(url, headers=headers)

# %%
html = res.text

# %%
# html

# %%
html = urlopen(url)

# %%
bs_obj = BeautifulSoup(html,'html.parser')

# %%
# # 토픽 추출
# #sp_nws1 > div.news_wrap.api_ani_send
# topic_list = bs_obj.findAll("div",{"class":"news_info"})
# # print(topic_list)

# %%
print(bs_obj.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="always" name="referrer"/>
#   <meta content="telephone=no,address=no,email=no" name="format-detection"/>
#   <meta content="width=device-width,initial-scale=1.0,maximum-scale=2.0" name="viewport"/>
#   <meta content="콘솔게임시장 현황 : 네이버 뉴스검색" property="og:title">
#    <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/>
#    <meta content="'콘솔게임시장 현황'의 네이버 뉴스검색 결과입니다." property="og:description"/>
#    <meta content="'콘솔게임시장 현황'의 네이버 뉴스검색 결과입니다." lang="ko" name="description"/>
#    <title>
#     콘솔게임시장 현황 : 네이버 뉴스검색
#    </title>
#    <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/>
#    <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml">
# ...

# %%
# 네이버 뉴스 본문 수집
news_title = bs_obj.findAll('a',{'class':'info press'})

# %%
print(news_title)
# Out:
# [<a class="info press" href="http://www.sportsseoul.com/" onclick="return goOtherCR(this, 'a=nws*a.prof&amp;r=1&amp;i=88156f78_000000000000000000942223&amp;g=468.0000942223&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F468%2F2020%2F12%2F08%2Flogo_468_18_20201208152603.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="..." width="20"/></span>스포츠서울</a>, <a class="info press" href="http://www.inews24.com/" onclick="return goOtherCR(this, 'a=nws*e.prof&amp;r=3&amp;i=880000D6_000000000000000000745701&amp;g=031.0000745701&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F
# ...

# %%
# 뉴스 링크 수집
news_link = bs_obj.select('#sp_nws1 > div.news_wrap.api_ani_send > div > div.news_info')
news_link[0]
# Out:
# <div class="news_info"> <div class="api_save_group _keep_wrap"> <a aria-pressed="false" class="btn_save _keep_trigger" data-url="https://www.sportsseoul.com/news/read/1310770?ref=naver" href="#" onclick="tCR('a=nws*a.kep&amp;r=1&amp;i=88156f78_000000000000000000942223&amp;u=javascript'); return false;" role="button"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws*a.kepoff&amp;r=1&amp;i=88156f78_000000000000000000942223&amp;u=javascript" data-cr-on="a=nws*a.kepon&amp;r=1&amp;i=88156f78_000000000000000000942223&amp;u=javascript" href="#" role="button">Keep에 저장</a> <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws*a.kephome&amp;r=1&amp;i=88156f78_000000000000000000942223&amp;u='+urlencode(this.href));" target="_blank">Keep 바로가기</a> </div></div><div class="info_group"> <a class="info press" href="http://www.sportsseoul.com/" onclick=
# ...

# %%
type(news_title) # bs4.element.ResultSet
type(news_link) # bs4.element.ResultSet
# Out:
# bs4.element.ResultSet

# %%
# elemnet.Tag 객체는 반복순환 가능
for u in news_title :
    print(u)
# Out:
# <a class="info press" href="http://www.sportsseoul.com/" onclick="return goOtherCR(this, 'a=nws*a.prof&amp;r=1&amp;i=88156f78_000000000000000000942223&amp;g=468.0000942223&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F468%2F2020%2F12%2F08%2Flogo_468_18_20201208152603.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="..." width="20"/></span>스포츠서울</a>
# ...

# %%
lis = news_title.findAll('a')
lis
# for li in lis :
#     print(li.text)
#     print(li.find('a')['href'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[258], line 1
# ----> 1 lis = news_title.findAll('a')
#       2 lis
#
# File ~\anaconda3\lib\site-packages\bs4\element.py:2289, in ResultSet.__getattr__(self, key)
#    2287 def __getattr__(self, key):
#    2288     """Raise a helpful exception to explain a common code fix."""
# -> 2289     raise AttributeError(
#    2290         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291     )
#
# AttributeError: ResultSet object has no attribute 'findAll'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
# # 전체 토픽 title과 link 출력
# for topic in topic_list : 
#     a_t = topic.find('span')
#     print(a_t.text.replace('\n',''))
# #     print(a_t['span'])
# # 마지막 부분에서 a태그가 없는 요소(빈item)가 있어서 에러 발생
# # 예외처리 진행

# %%
driver.close()

# %%
#  name = topic_list.find_element(By.CSS_SELECTOR,".news_info").text

# %%
# #.basicList_title__VfX3c
# for topic_list in topic_lists :
#     name = topic_list.find_element(By.CSS_SELECTOR,".news_info").text
# #     try : 
# # #         price = item.find_element(By.CSS_SELECTOR,".a").text
# #     except :
# #         price = '판매중단'
#     link = item.find_element(By.CSS_SELECTOR,".a").get_attribute('href')
#     print(name,link)
